# %%
import requests
import pandas as pd

def fetch_weather(lat, lon, start_date, end_date):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat,
        "longitude": lon,
        "hourly": "temperature_2m,wind_speed_10m,shortwave_radiation",
        "start_date": start_date,
        "end_date": end_date,
        "timezone": "Europe/Copenhagen"
    }
    r = requests.get(url, params=params)
    r.raise_for_status()
    data = r.json()["hourly"]
    return pd.DataFrame(data).set_index(
        pd.to_datetime(data["time"])
    )

df = fetch_weather(56.0, 10.0, "2024-01-01", "2024-03-31")

# %%
df.head(2)
# Out:
#                                  time  temperature_2m  wind_speed_10m  \
# 2024-01-01 00:00:00  2024-01-01T00:00             5.4            13.0
# 2024-01-01 01:00:00  2024-01-01T01:00             5.3            11.9
#
#                      shortwave_radiation
# 2024-01-01 00:00:00                  0.0
# 2024-01-01 01:00:00                  0.0
